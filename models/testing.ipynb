# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Load and display dtypes for channel_stats
channel_stats = pd.read_csv('/content/drive/Othercomputers/My Laptop/models/channel_stats_rows.csv')
print("channel_stats columns and dtypes:")
print(channel_stats.dtypes)
print("\n")

# Load and display dtypes for videos_rows
videos_rows = pd.read_csv('/content/drive/Othercomputers/My Laptop/models/videos_rows.csv')
print("videos_rows columns and dtypes:")
print(videos_rows.dtypes)
print("\n")

# Load and display dtypes for view_timeseries
view_timeseries = pd.read_csv('/content/drive/Othercomputers/My Laptop/models/view_timeseries.csv')
print("view_timeseries columns and dtypes:")
print(view_timeseries.dtypes)
# Out:
# channel_stats columns and dtypes:
# channel_id              object
# channel_title           object
# channel_description    float64
# published_at           float64
# country                 object
# total_views              int64
# subscriber_count         int64
# video_count              int64
# processed_at            object
# created_at              object
# title                   object
# tier_category          float64
# uploads_playlist_id     object
# last_checked_at        float64
# dtype: object
#
#
# videos_rows columns and dtypes:
# video_id                   object
# channel_id                 object
# published_at               object
# status                     object
# last_polled_at             object
# next_poll_at               object
# current_interval_hours    float64
# created_at                 object
# dtype: object
#
#
# view_timeseries columns and dtypes:
# id               object
# video_id         object
# scraped_at       object
# ...
